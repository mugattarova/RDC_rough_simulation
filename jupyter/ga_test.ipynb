# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga

def f(X):
    return -81

model=ga(function=f, dimension=5, variable_type='bool')

model.run()
# Out:
#  The best solution found:
#  [0. 1. 0. 1. 1.]
#
#  Objective function:
#  -81
